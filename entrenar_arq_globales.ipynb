# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms
import sklearn.metrics as metrics
import pandas as pd
import numpy as np
from torch_geometric.data import Data
import pandapower as pp
import networkx as nx
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split

from torch.utils.tensorboard import SummaryWriter
from arquitecturas import GNN_global, FCNN_global
from metric import NormalizedError
# Out:
# /home/iboero/miniconda3/envs/proy/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/iboero/miniconda3/envs/proy/lib/python3.11/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /tmp/ipykernel_29402/2187797291.py:11: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
if torch.cuda.is_available():
  device = 'cuda'
else:
  device = 'cpu'

red = "118" # o 118

# %% [markdown]
# ## Levantar Topologia de Red

# %%
# Levantamos la red de IEEE118

if red=="30":
    net = pp.networks.case30()
    z_trafos = net.trafo[['hv_bus', 'lv_bus']].to_numpy().astype(np.int32)
else:
    net = pp.networks.case118()
    z_trafos =  np.array([
        [0, 0.0267],
        [0, 0.0382],
        [0, 0.0388],
        [0, 0.0375],
        [0, 0.0386],
        [0, 0.0268],
        [0, 0.0370],
        [0.0013, 0.016],
        [0, 0.0370],
        [0.0017, 0.0202],
        [0, 0.0370],
        [0.0282, 0.2074],
        [0.0003, 0.00405]
    ])

# Armar matirz de adyacencia
lineas = net.line[['from_bus', 'to_bus']].to_numpy().astype(np.int32)
trafos = net.trafo[['hv_bus', 'lv_bus']].to_numpy().astype(np.int32)
edge_index = np.append(lineas, trafos,axis=0)
edge_index = torch.Tensor(edge_index).t().type(torch.int64).to(device)


# Armar matriz de pesos
k = 10
z_lineas =  net.line[['r_ohm_per_km', 'x_ohm_per_km']].to_numpy() * 100 / np.expand_dims((net.bus['vn_kv'].to_numpy()[net.line['from_bus'].to_numpy()])**2,axis=1)
edge_weights = np.append(z_lineas, z_trafos,axis=0)
edge_weights = torch.Tensor(np.e**(-k*(edge_weights[:,0]**2 + edge_weights[:,1]**2))).to(device)

# Armar mascara de generadores para la salida
idx_gen = net.gen["bus"].to_numpy()
idx_grid = net.ext_grid["bus"].to_numpy()
idx_gens = np.append(idx_gen,idx_grid,axis=0)
feature_mask = np.zeros(len(net.bus.index), dtype=int)
feature_mask[idx_gens] = 1
feature_mask = torch.Tensor(feature_mask).type(torch.int32).to(device)
# Out:
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /home/iboero/.local/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)

# %% [markdown]
# ## Levanatar Datos

# %%
# Levantar los datos
datos_path = './data'

if red == "30":
    X = np.load(datos_path+'/input30.npy')
    y = np.load(datos_path+'/p_opt30.npy')
else:
    X = np.load(datos_path+'/input118.npy')
    y = np.load(datos_path+'/p_opt118.npy')

# Separar en X e Y 
X_tensor = torch.Tensor(X).to(device)
y_tensor_global = torch.Tensor(y[:,:,0]).to(device)[:, feature_mask == 1]

# %%
# Generar loaders para el entrenamiento
batch_size = 128

dataset_global = TensorDataset(X_tensor, y_tensor_global)
data_train_global ,data_test_global  = train_test_split(dataset_global ,test_size=0.2,random_state=42)
data_train_global ,data_val_global  = train_test_split(data_train_global ,test_size=0.1,random_state=42)

train_loader_global  = DataLoader(data_train_global , batch_size=batch_size)
val_loader_global  = DataLoader(data_val_global , batch_size=batch_size)
test_loader_global  = DataLoader(data_test_global , batch_size=batch_size)

# %% [markdown]
# ## Entrenamiento

# %% [markdown]
# ### Funciones antrenamiento y evaluacion

# %%
# Definimos la funcion de entrenamiento
def train_global(model, train_loader, optimizer, criterion,epoch=None,writer=None):
    model.train()
    total_loss = 0
    total_metric = 0
    normalized_error = NormalizedError()

    for data in train_loader:
        optimizer.zero_grad()
        output = model(data[0])
        target = data[1]
        loss = criterion(output, target) 
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        # Calcular la métrica
        metric = normalized_error(output, target)
        total_metric += metric.item()

    avg_loss = total_loss / len(train_loader)
    avg_metric = total_metric / len(train_loader)

    writer.add_scalar('Train/Training Loss', avg_loss, epoch)
    writer.add_scalar('Train/Training Metric', avg_metric, epoch)
    
    return avg_loss, avg_metric


# Definimos la funcion de evaluacion
def evaluate_global(model, data_loader, criterion,epoch=None,writer=None,test=False):
    model.eval()
    total_loss = 0
    total_metric = 0
    normalized_error = NormalizedError()

    with torch.no_grad():
        for data in data_loader:
            output = model(data[0])
            target = data[1]
            loss = criterion(output, target)  # target should contain true values for nodes with missing features
            total_loss += loss.item()
            # Calcular la métrica
            metric = normalized_error(output, target)
            total_metric += metric.item()

    avg_loss = total_loss / len(data_loader)
    avg_metric = total_metric / len(data_loader)

    if epoch != None:
        writer.add_scalar('Val/Validation Loss', avg_loss, epoch)
        writer.add_scalar('Val/Validation Metric', avg_metric, epoch)
    
    return avg_loss, avg_metric

# %% [markdown]
# ### GNN

# %%
writer_gnn = SummaryWriter('resultados/gnn_global_'+red)

# Hiperparametros
num_nodes = len(net.bus)
num_gens = len(net.gen) +len(net.ext_grid)
dim = [4,128,64,1]
num_layers = 3
K = [5,5]
num_epochs = 200

if red == "118":
    lr = 0.0001
else:
    lr = 0.0002

# Definicion Modelo, Optimizer y Loss
model_gnn = GNN_global(dim, edge_index,edge_weights, num_layers, K, num_nodes, num_gens,batch_norm=False).to(device)
optimizer = torch.optim.Adam(model_gnn.parameters(), lr=lr)
criterion = nn.MSELoss()

# Entrenamiento
for epoch in range(num_epochs):
    train_loss, train_metric = train_global(model_gnn, train_loader_global, optimizer, criterion,epoch,writer_gnn)
    val_loss, val_metric = evaluate_global(model_gnn, val_loader_global, criterion, epoch,writer_gnn)
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Metric: {train_metric:.4f},  Val Loss: {val_loss:.4f}, Val Metric: {val_metric:.4f}")

# Evaluacion
test_loss, test_metric = evaluate_global(model_gnn, test_loader_global, criterion,None,writer_gnn)
print(f"Test Loss: {test_loss:.5f}, Test Metric: {test_metric:.5f}")
# Out:
# Epoch 1/200, Train Loss: 3934.6426, Train Metric: 0.4707,  Val Loss: 40.1176, Val Metric: 0.2006
# Epoch 2/200, Train Loss: 11.7675, Train Metric: 0.1383,  Val Loss: 6.1383, Val Metric: 0.1171
# Epoch 3/200, Train Loss: 6.1627, Train Metric: 0.1171,  Val Loss: 5.5537, Val Metric: 0.1143
# Epoch 4/200, Train Loss: 5.6772, Train Metric: 0.1150,  Val Loss: 5.1494, Val Metric: 0.1124
# Epoch 184/200, Train Loss: 0.1763, Train Metric: 0.0512,  Val Loss: 0.1269, Val Metric: 0.0472
# Epoch 185/200, Train Loss: 0.3186, Train Metric: 0.0556,  Val Loss: 0.3086, Val Metric: 0.0593
# Epoch 186/200, Train Loss: 0.1662, Train Metric: 0.0504,  Val Loss: 0.1803, Val Metric: 0.0519
# Epoch 187/200, Train Loss: 0.1835, Train Metric: 0.0517,  Val Loss: 0.2345, Val Metric: 0.0552
# Epoch 188/200, Train Loss: 0.2706, Train Metric: 0.0552,  Val Loss: 1.1646, Val Metric: 0.0828
# Epoch 189/200, Train Loss: 0.2988, Train Metric: 0.0565,  Val Loss: 0.0985, Val Metric: 0.0444
# Epoch 190/200, Train Loss: 0.1590, Train Metric: 0.0498,  Val Loss: 0.1042, Val Metric: 0.0452
# Epoch 191/200, Train Loss: 0.2024, Train Metric: 0.0525,  Val Loss: 0.4288, Val Metric: 0.0643
# Epoch 192/200, Train Loss: 0.1818, Train Metric: 0.0511,  Val Loss: 0.1919, Val Metric: 0.0526
# Epoch 193/200, Train Loss: 0.2376, Train Metric: 0.0547,  Val Loss: 0.0981, Val Metric: 0.0445
# Epoch 194/200, Train Loss: 0.2061, Train Metric: 0.0513,  Val Loss: 1.6301, Val Metric: 0.0901
# Epoch 195/200, Train Loss: 0.3901, Train Metric: 0.0581,  Val Loss: 0.0802, Val Metric: 0.0423
# Epoch 196/200, Train Loss: 0.1518, Train Metric: 0.0491,  Val Loss: 0.0822, Val Metric: 0.0424
# Epoch 197/200, Train Loss: 0.1612, Train Metric: 0.0496,  Val Loss: 0.1063, Val Metric: 0.0453
# Epoch 198/200, Train Loss: 0.2379, Train Metric: 0.0537,  Val Loss: 0.1140, Val Metric: 0.0462
# Epoch 199/200, Train Loss: 0.1603, Train Metric: 0.0499,  Val Loss: 0.1838, Val Metric: 0.0518
# Epoch 200/200, Train Loss: 0.2261, Train Metric: 0.0541,  Val Loss: 0.1788, Val Metric: 0.0514
# Test Loss: 0.18322, Test Metric: 0.05168

# %% [markdown]
# ### FCNN

# %%
writer_fcnn = SummaryWriter('resultados/fcnn_global_'+red)

# Hiperparametros
num_nodes = len(net.bus)
num_gens = len(net.gen) +len(net.ext_grid)
dim = [4*num_nodes,128,64,num_gens]
num_layers = 3
num_epochs = 200
if red == "118":
    lr = 0.0003
else:
    lr = 0.00005

# Definicion Modelo, Optimizer y Loss
model_fcnn = FCNN_global(dim, num_layers).to(device)
optimizer = torch.optim.Adam(model_fcnn.parameters(), lr=lr)
criterion = nn.MSELoss()  # Change the loss function as needed

# Entrenamiento
for epoch in range(num_epochs):
    train_loss, train_metric = train_global(model_fcnn, train_loader_global, optimizer, criterion,epoch,writer_fcnn)
    val_loss, val_metric = evaluate_global(model_fcnn, val_loader_global, criterion, epoch,writer_fcnn)
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Metric: {train_metric:.4f},  Val Loss: {val_loss:.4f}, Val Metric: {val_metric:.4f}")

# Evaluacion
test_loss, test_metric = evaluate_global(model_fcnn, test_loader_global, criterion,None,writer_fcnn)
print(f"Test Loss: {test_loss:.5f}, Test Metric: {test_metric:.5f}")
# Out:
# Epoch 1/200, Train Loss: 14610.9127, Train Metric: 0.8422,  Val Loss: 1580.5119, Val Metric: 0.5015
# Epoch 2/200, Train Loss: 218.5167, Train Metric: 0.2368,  Val Loss: 4.1995, Val Metric: 0.1128
# Epoch 3/200, Train Loss: 2.5504, Train Metric: 0.0983,  Val Loss: 2.1716, Val Metric: 0.0945
# Epoch 4/200, Train Loss: 2.1933, Train Metric: 0.0947,  Val Loss: 2.1609, Val Metric: 0.0944
# Epoch 5/200, Train Loss: 2.1895, Train Metric: 0.0946,  Val Loss: 2.1546, Val Metric: 0.0943
# Epoch 6/200, Train Loss: 2.1856, Train Metric: 0.0946,  Val Loss: 2.1485, Val Metric: 0.0943
# Epoch 7/200, Train Loss: 2.1811, Train Metric: 0.0946,  Val Loss: 2.1436, Val Metric: 0.0942
# Epoch 8/200, Train Loss: 2.1763, Train Metric: 0.0945,  Val Loss: 2.1391, Val Metric: 0.0942
# Epoch 9/200, Train Loss: 2.1713, Train Metric: 0.0945,  Val Loss: 2.1346, Val Metric: 0.0942
# Epoch 10/200, Train Loss: 2.1661, Train Metric: 0.0944,  Val Loss: 2.1301, Val Metric: 0.0941
# Epoch 11/200, Train Loss: 2.1608, Train Metric: 0.0944,  Val Loss: 2.1255, Val Metric: 0.0941
# Epoch 12/200, Train Loss: 2.1553, Train Metric: 0.0943,  Val Loss: 2.1207, Val Metric: 0.0940
# Epoch 13/200, Train Loss: 2.1497, Train Metric: 0.0943,  Val Loss: 2.1153, Val Metric: 0.0940
# Epoch 14/200, Train Loss: 2.1440, Train Metric: 0.0942,  Val Loss: 2.1095, Val Metric: 0.0939
# Epoch 15/200, Train Loss: 2.1382, Train Metric: 0.0942,  Val Loss: 2.1038, Val Metric: 0.0939
# Epoch 16/200, Train Loss: 2.1322, Train Metric: 0.0941,  Val Loss: 2.0979, Val Metric: 0.0938
# Epoch 17/200, Train Loss: 2.1260, Train Metric: 0.0940,  Val Loss: 2.0921, Val Metric: 0.0937
# Epoch 18/200, Train Loss: 2.1198, Train Metric: 0.0940,  Val Loss: 2.0860, Val Metric: 0.0937
# Epoch 19/200, Train Loss: 2.1132, Train Metric: 0.0939,  Val Loss: 2.0797, Val Metric: 0.0936
# Epoch 20/200, Train Loss: 2.1065, Train Metric: 0.0939,  Val Loss: 2.0735, Val Metric: 0.0936
# Epoch 21/200, Train Loss: 2.0994, Train Metric: 0.0938,  Val Loss: 2.0673, Val Metric: 0.0935
# Epoch 22/200, Train Loss: 2.0921, Train Metric: 0.0937,  Val Loss: 2.0610, Val Metric: 0.0934
# Epoch 23/200, Train Loss: 2.0845, Train Metric: 0.0936,  Val Loss: 2.0544, Val Metric: 0.0934
# Epoch 24/200, Train Loss: 2.0769, Train Metric: 0.0936,  Val Loss: 2.0474, Val Metric: 0.0933
# Epoch 25/200, Train Loss: 2.0692, Train Metric: 0.0935,  Val Loss: 2.0401, Val Metric: 0.0932
# Epoch 26/200, Train Loss: 2.0613, Train Metric: 0.0934,  Val Loss: 2.0326, Val Metric: 0.0932
# Epoch 27/200, Train Loss: 2.0534, Train Metric: 0.0933,  Val Loss: 2.0250, Val Metric: 0.0931
# Epoch 28/200, Train Loss: 2.0453, Train Metric: 0.0933,  Val Loss: 2.0174, Val Metric: 0.0930
# Epoch 29/200, Train Loss: 2.0372, Train Metric: 0.0932,  Val Loss: 2.0096, Val Metric: 0.0929
# Epoch 30/200, Train Loss: 2.0290, Train Metric: 0.0931,  Val Loss: 2.0012, Val Metric: 0.0928
# Epoch 31/200, Train Loss: 2.0207, Train Metric: 0.0930,  Val Loss: 1.9923, Val Metric: 0.0928
# Epoch 32/200, Train Loss: 2.0123, Train Metric: 0.0929,  Val Loss: 1.9830, Val Metric: 0.0927
# Epoch 33/200, Train Loss: 2.0035, Train Metric: 0.0928,  Val Loss: 1.9740, Val Metric: 0.0926
# Epoch 34/200, Train Loss: 1.9946, Train Metric: 0.0927,  Val Loss: 1.9653, Val Metric: 0.0925
# Epoch 35/200, Train Loss: 1.9855, Train Metric: 0.0926,  Val Loss: 1.9570, Val Metric: 0.0924
# Epoch 36/200, Train Loss: 1.9764, Train Metric: 0.0925,  Val Loss: 1.9490, Val Metric: 0.0923
# Epoch 37/200, Train Loss: 1.9674, Train Metric: 0.0924,  Val Loss: 1.9414, Val Metric: 0.0922
# Epoch 38/200, Train Loss: 1.9585, Train Metric: 0.0923,  Val Loss: 1.9337, Val Metric: 0.0921
# Epoch 39/200, Train Loss: 1.9497, Train Metric: 0.0923,  Val Loss: 1.9258, Val Metric: 0.0921
# Epoch 40/200, Train Loss: 1.9409, Train Metric: 0.0922,  Val Loss: 1.9178, Val Metric: 0.0920
# Epoch 41/200, Train Loss: 1.9320, Train Metric: 0.0921,  Val Loss: 1.9095, Val Metric: 0.0919
# Epoch 42/200, Train Loss: 1.9230, Train Metric: 0.0920,  Val Loss: 1.9009, Val Metric: 0.0918
# Epoch 43/200, Train Loss: 1.9139, Train Metric: 0.0919,  Val Loss: 1.8919, Val Metric: 0.0917
# Epoch 44/200, Train Loss: 1.9045, Train Metric: 0.0918,  Val Loss: 1.8821, Val Metric: 0.0916
# Epoch 45/200, Train Loss: 1.8949, Train Metric: 0.0917,  Val Loss: 1.8715, Val Metric: 0.0915
# Epoch 46/200, Train Loss: 1.8852, Train Metric: 0.0916,  Val Loss: 1.8600, Val Metric: 0.0913
# Epoch 47/200, Train Loss: 1.8752, Train Metric: 0.0914,  Val Loss: 1.8479, Val Metric: 0.0912
# Epoch 48/200, Train Loss: 1.8650, Train Metric: 0.0913,  Val Loss: 1.8353, Val Metric: 0.0910
# Epoch 49/200, Train Loss: 1.8546, Train Metric: 0.0912,  Val Loss: 1.8227, Val Metric: 0.0909
# Epoch 50/200, Train Loss: 1.8442, Train Metric: 0.0911,  Val Loss: 1.8106, Val Metric: 0.0908
# Epoch 51/200, Train Loss: 1.8338, Train Metric: 0.0910,  Val Loss: 1.7989, Val Metric: 0.0906
# Epoch 52/200, Train Loss: 1.8234, Train Metric: 0.0909,  Val Loss: 1.7878, Val Metric: 0.0905
# Epoch 53/200, Train Loss: 1.8129, Train Metric: 0.0907,  Val Loss: 1.7769, Val Metric: 0.0904
# Epoch 54/200, Train Loss: 1.8022, Train Metric: 0.0906,  Val Loss: 1.7661, Val Metric: 0.0903
# Epoch 55/200, Train Loss: 1.7912, Train Metric: 0.0905,  Val Loss: 1.7549, Val Metric: 0.0901
# Epoch 56/200, Train Loss: 1.7797, Train Metric: 0.0904,  Val Loss: 1.7431, Val Metric: 0.0900
# Epoch 57/200, Train Loss: 1.7677, Train Metric: 0.0902,  Val Loss: 1.7305, Val Metric: 0.0898
# Epoch 58/200, Train Loss: 1.7550, Train Metric: 0.0901,  Val Loss: 1.7176, Val Metric: 0.0897
# Epoch 59/200, Train Loss: 1.7418, Train Metric: 0.0899,  Val Loss: 1.7047, Val Metric: 0.0895
# Epoch 60/200, Train Loss: 1.7281, Train Metric: 0.0898,  Val Loss: 1.6920, Val Metric: 0.0894
# Epoch 61/200, Train Loss: 1.7141, Train Metric: 0.0896,  Val Loss: 1.6793, Val Metric: 0.0892
# Epoch 62/200, Train Loss: 1.6999, Train Metric: 0.0894,  Val Loss: 1.6663, Val Metric: 0.0891
# Epoch 63/200, Train Loss: 1.6856, Train Metric: 0.0892,  Val Loss: 1.6527, Val Metric: 0.0889
# Epoch 64/200, Train Loss: 1.6710, Train Metric: 0.0891,  Val Loss: 1.6388, Val Metric: 0.0887
# Epoch 65/200, Train Loss: 1.6561, Train Metric: 0.0889,  Val Loss: 1.6245, Val Metric: 0.0885
# Epoch 66/200, Train Loss: 1.6409, Train Metric: 0.0887,  Val Loss: 1.6105, Val Metric: 0.0883
# Epoch 67/200, Train Loss: 1.6255, Train Metric: 0.0885,  Val Loss: 1.5964, Val Metric: 0.0882
# Epoch 68/200, Train Loss: 1.6101, Train Metric: 0.0883,  Val Loss: 1.5739, Val Metric: 0.0878
# Epoch 69/200, Train Loss: 1.5809, Train Metric: 0.0879,  Val Loss: 1.5433, Val Metric: 0.0874
# Epoch 70/200, Train Loss: 1.5517, Train Metric: 0.0875,  Val Loss: 1.5229, Val Metric: 0.0871
# Epoch 71/200, Train Loss: 1.5292, Train Metric: 0.0871,  Val Loss: 1.5046, Val Metric: 0.0869
# Epoch 72/200, Train Loss: 1.5094, Train Metric: 0.0869,  Val Loss: 1.4886, Val Metric: 0.0866
# Epoch 73/200, Train Loss: 1.4920, Train Metric: 0.0866,  Val Loss: 1.4749, Val Metric: 0.0864
# Epoch 74/200, Train Loss: 1.4765, Train Metric: 0.0864,  Val Loss: 1.4630, Val Metric: 0.0863
# Epoch 75/200, Train Loss: 1.4626, Train Metric: 0.0862,  Val Loss: 1.4524, Val Metric: 0.0861
# Epoch 76/200, Train Loss: 1.4499, Train Metric: 0.0860,  Val Loss: 1.4428, Val Metric: 0.0860
# Epoch 77/200, Train Loss: 1.4381, Train Metric: 0.0858,  Val Loss: 1.4338, Val Metric: 0.0858
# Epoch 78/200, Train Loss: 1.4270, Train Metric: 0.0856,  Val Loss: 1.4251, Val Metric: 0.0857
# Epoch 79/200, Train Loss: 1.4165, Train Metric: 0.0855,  Val Loss: 1.4165, Val Metric: 0.0856
# Epoch 80/200, Train Loss: 1.4066, Train Metric: 0.0853,  Val Loss: 1.4080, Val Metric: 0.0855
# Epoch 81/200, Train Loss: 1.3973, Train Metric: 0.0852,  Val Loss: 1.3998, Val Metric: 0.0853
# Epoch 82/200, Train Loss: 1.3884, Train Metric: 0.0851,  Val Loss: 1.3920, Val Metric: 0.0852
# Epoch 83/200, Train Loss: 1.3799, Train Metric: 0.0849,  Val Loss: 1.3845, Val Metric: 0.0851
# Epoch 84/200, Train Loss: 1.3718, Train Metric: 0.0848,  Val Loss: 1.3771, Val Metric: 0.0850
# Epoch 85/200, Train Loss: 1.3640, Train Metric: 0.0847,  Val Loss: 1.3697, Val Metric: 0.0849
# Epoch 86/200, Train Loss: 1.3563, Train Metric: 0.0846,  Val Loss: 1.3624, Val Metric: 0.0848
# Epoch 87/200, Train Loss: 1.3489, Train Metric: 0.0845,  Val Loss: 1.3555, Val Metric: 0.0847
# Epoch 88/200, Train Loss: 1.3416, Train Metric: 0.0844,  Val Loss: 1.3494, Val Metric: 0.0846
# Epoch 89/200, Train Loss: 1.3343, Train Metric: 0.0842,  Val Loss: 1.3426, Val Metric: 0.0845
# Epoch 90/200, Train Loss: 1.3267, Train Metric: 0.0841,  Val Loss: 1.3347, Val Metric: 0.0844
# Epoch 91/200, Train Loss: 1.3190, Train Metric: 0.0840,  Val Loss: 1.3264, Val Metric: 0.0842
# Epoch 92/200, Train Loss: 1.3112, Train Metric: 0.0839,  Val Loss: 1.3183, Val Metric: 0.0841
# Epoch 93/200, Train Loss: 1.3035, Train Metric: 0.0838,  Val Loss: 1.3104, Val Metric: 0.0840
# Epoch 94/200, Train Loss: 1.2961, Train Metric: 0.0837,  Val Loss: 1.3026, Val Metric: 0.0839
# Epoch 95/200, Train Loss: 1.2888, Train Metric: 0.0835,  Val Loss: 1.2949, Val Metric: 0.0837
# Epoch 96/200, Train Loss: 1.2818, Train Metric: 0.0834,  Val Loss: 1.2874, Val Metric: 0.0836
# Epoch 97/200, Train Loss: 1.2749, Train Metric: 0.0833,  Val Loss: 1.2804, Val Metric: 0.0835
# Epoch 98/200, Train Loss: 1.2683, Train Metric: 0.0832,  Val Loss: 1.2737, Val Metric: 0.0834
# Epoch 99/200, Train Loss: 1.2617, Train Metric: 0.0831,  Val Loss: 1.2673, Val Metric: 0.0833
# Epoch 100/200, Train Loss: 1.2553, Train Metric: 0.0830,  Val Loss: 1.2612, Val Metric: 0.0832
# Epoch 101/200, Train Loss: 1.2489, Train Metric: 0.0829,  Val Loss: 1.2553, Val Metric: 0.0831
# Epoch 102/200, Train Loss: 1.2426, Train Metric: 0.0828,  Val Loss: 1.2494, Val Metric: 0.0830
# Epoch 103/200, Train Loss: 1.2363, Train Metric: 0.0827,  Val Loss: 1.2436, Val Metric: 0.0829
# Epoch 104/200, Train Loss: 1.2301, Train Metric: 0.0826,  Val Loss: 1.2377, Val Metric: 0.0828
# Epoch 105/200, Train Loss: 1.2239, Train Metric: 0.0825,  Val Loss: 1.2317, Val Metric: 0.0827
# Epoch 106/200, Train Loss: 1.2178, Train Metric: 0.0824,  Val Loss: 1.2255, Val Metric: 0.0826
# Epoch 107/200, Train Loss: 1.2116, Train Metric: 0.0823,  Val Loss: 1.2191, Val Metric: 0.0825
# Epoch 108/200, Train Loss: 1.2054, Train Metric: 0.0822,  Val Loss: 1.2126, Val Metric: 0.0824
# Epoch 109/200, Train Loss: 1.1992, Train Metric: 0.0821,  Val Loss: 1.2060, Val Metric: 0.0823
# Epoch 110/200, Train Loss: 1.1929, Train Metric: 0.0820,  Val Loss: 1.1996, Val Metric: 0.0822
# Epoch 111/200, Train Loss: 1.1868, Train Metric: 0.0819,  Val Loss: 1.1933, Val Metric: 0.0821
# Epoch 112/200, Train Loss: 1.1804, Train Metric: 0.0818,  Val Loss: 1.1870, Val Metric: 0.0820
# Epoch 113/200, Train Loss: 1.1741, Train Metric: 0.0817,  Val Loss: 1.1807, Val Metric: 0.0819
# Epoch 114/200, Train Loss: 1.1676, Train Metric: 0.0816,  Val Loss: 1.1744, Val Metric: 0.0818
# Epoch 115/200, Train Loss: 1.1609, Train Metric: 0.0815,  Val Loss: 1.1680, Val Metric: 0.0816
# Epoch 116/200, Train Loss: 1.1540, Train Metric: 0.0814,  Val Loss: 1.1617, Val Metric: 0.0815
# Epoch 117/200, Train Loss: 1.1469, Train Metric: 0.0812,  Val Loss: 1.1556, Val Metric: 0.0814
# Epoch 118/200, Train Loss: 1.1399, Train Metric: 0.0811,  Val Loss: 1.1499, Val Metric: 0.0813
# Epoch 119/200, Train Loss: 1.1330, Train Metric: 0.0810,  Val Loss: 1.1446, Val Metric: 0.0812
# Epoch 120/200, Train Loss: 1.1263, Train Metric: 0.0809,  Val Loss: 1.1398, Val Metric: 0.0812
# Epoch 121/200, Train Loss: 1.1199, Train Metric: 0.0808,  Val Loss: 1.1355, Val Metric: 0.0811
# Epoch 122/200, Train Loss: 1.1136, Train Metric: 0.0806,  Val Loss: 1.1313, Val Metric: 0.0810
# Epoch 123/200, Train Loss: 1.1074, Train Metric: 0.0805,  Val Loss: 1.1266, Val Metric: 0.0809
# Epoch 124/200, Train Loss: 1.1012, Train Metric: 0.0804,  Val Loss: 1.1213, Val Metric: 0.0808
# Epoch 125/200, Train Loss: 1.0950, Train Metric: 0.0803,  Val Loss: 1.1151, Val Metric: 0.0807
# Epoch 126/200, Train Loss: 1.0887, Train Metric: 0.0802,  Val Loss: 1.1083, Val Metric: 0.0806
# Epoch 127/200, Train Loss: 1.0825, Train Metric: 0.0801,  Val Loss: 1.1011, Val Metric: 0.0805
# Epoch 128/200, Train Loss: 1.0762, Train Metric: 0.0800,  Val Loss: 1.0938, Val Metric: 0.0804
# Epoch 129/200, Train Loss: 1.0871, Train Metric: 0.0802,  Val Loss: 1.0851, Val Metric: 0.0802
# Epoch 130/200, Train Loss: 1.0434, Train Metric: 0.0794,  Val Loss: 1.0432, Val Metric: 0.0794
# Epoch 131/200, Train Loss: 1.0301, Train Metric: 0.0791,  Val Loss: 1.0341, Val Metric: 0.0792
# Epoch 132/200, Train Loss: 1.0218, Train Metric: 0.0790,  Val Loss: 1.0247, Val Metric: 0.0791
# Epoch 133/200, Train Loss: 1.0143, Train Metric: 0.0788,  Val Loss: 1.0144, Val Metric: 0.0789
# Epoch 134/200, Train Loss: 1.0072, Train Metric: 0.0787,  Val Loss: 1.0037, Val Metric: 0.0786
# Epoch 135/200, Train Loss: 1.0003, Train Metric: 0.0786,  Val Loss: 0.9930, Val Metric: 0.0784
# Epoch 136/200, Train Loss: 0.9933, Train Metric: 0.0784,  Val Loss: 0.9827, Val Metric: 0.0782
# Epoch 137/200, Train Loss: 0.9864, Train Metric: 0.0783,  Val Loss: 0.9729, Val Metric: 0.0780
# Epoch 138/200, Train Loss: 0.9793, Train Metric: 0.0782,  Val Loss: 0.9633, Val Metric: 0.0778
# Epoch 139/200, Train Loss: 0.9722, Train Metric: 0.0780,  Val Loss: 0.9542, Val Metric: 0.0776
# Epoch 140/200, Train Loss: 0.9651, Train Metric: 0.0779,  Val Loss: 0.9453, Val Metric: 0.0775
# Epoch 141/200, Train Loss: 0.9579, Train Metric: 0.0777,  Val Loss: 0.9366, Val Metric: 0.0773
# Epoch 142/200, Train Loss: 0.9508, Train Metric: 0.0776,  Val Loss: 0.9281, Val Metric: 0.0771
# Epoch 143/200, Train Loss: 0.9436, Train Metric: 0.0774,  Val Loss: 0.9198, Val Metric: 0.0769
# Epoch 144/200, Train Loss: 0.9365, Train Metric: 0.0773,  Val Loss: 0.9115, Val Metric: 0.0768
# Epoch 145/200, Train Loss: 0.9293, Train Metric: 0.0771,  Val Loss: 0.9035, Val Metric: 0.0766
# Epoch 146/200, Train Loss: 0.9222, Train Metric: 0.0770,  Val Loss: 0.8955, Val Metric: 0.0764
# Epoch 147/200, Train Loss: 0.9150, Train Metric: 0.0768,  Val Loss: 0.8878, Val Metric: 0.0763
# Epoch 148/200, Train Loss: 0.9079, Train Metric: 0.0767,  Val Loss: 0.8801, Val Metric: 0.0761
# Epoch 149/200, Train Loss: 0.9007, Train Metric: 0.0765,  Val Loss: 0.8726, Val Metric: 0.0759
# Epoch 150/200, Train Loss: 0.8937, Train Metric: 0.0764,  Val Loss: 0.8653, Val Metric: 0.0758
# Epoch 151/200, Train Loss: 0.8866, Train Metric: 0.0762,  Val Loss: 0.8582, Val Metric: 0.0756
# Epoch 178/200, Train Loss: 0.7158, Train Metric: 0.0722,  Val Loss: 0.7175, Val Metric: 0.0723
# Epoch 179/200, Train Loss: 0.7102, Train Metric: 0.0721,  Val Loss: 0.7108, Val Metric: 0.0721
# Epoch 180/200, Train Loss: 0.7047, Train Metric: 0.0719,  Val Loss: 0.7042, Val Metric: 0.0719
# Epoch 181/200, Train Loss: 0.6992, Train Metric: 0.0718,  Val Loss: 0.6975, Val Metric: 0.0717
# Epoch 182/200, Train Loss: 0.6938, Train Metric: 0.0716,  Val Loss: 0.6909, Val Metric: 0.0716
# Epoch 183/200, Train Loss: 0.6884, Train Metric: 0.0715,  Val Loss: 0.6842, Val Metric: 0.0714
# Epoch 184/200, Train Loss: 0.6831, Train Metric: 0.0714,  Val Loss: 0.6776, Val Metric: 0.0712
# Epoch 185/200, Train Loss: 0.6778, Train Metric: 0.0712,  Val Loss: 0.6711, Val Metric: 0.0710
# Epoch 186/200, Train Loss: 0.6726, Train Metric: 0.0711,  Val Loss: 0.6646, Val Metric: 0.0708
# Epoch 187/200, Train Loss: 0.6674, Train Metric: 0.0709,  Val Loss: 0.6583, Val Metric: 0.0707
# Epoch 188/200, Train Loss: 0.6623, Train Metric: 0.0708,  Val Loss: 0.6521, Val Metric: 0.0705
# Epoch 189/200, Train Loss: 0.6572, Train Metric: 0.0707,  Val Loss: 0.6462, Val Metric: 0.0703
# Epoch 190/200, Train Loss: 0.6523, Train Metric: 0.0705,  Val Loss: 0.6404, Val Metric: 0.0702
# Epoch 191/200, Train Loss: 0.6474, Train Metric: 0.0704,  Val Loss: 0.6348, Val Metric: 0.0700
# Epoch 192/200, Train Loss: 0.6426, Train Metric: 0.0703,  Val Loss: 0.6295, Val Metric: 0.0699
# Epoch 193/200, Train Loss: 0.6378, Train Metric: 0.0701,  Val Loss: 0.6244, Val Metric: 0.0697
# Epoch 194/200, Train Loss: 0.6331, Train Metric: 0.0700,  Val Loss: 0.6196, Val Metric: 0.0696
# Epoch 195/200, Train Loss: 0.6285, Train Metric: 0.0699,  Val Loss: 0.6151, Val Metric: 0.0694
# Epoch 196/200, Train Loss: 0.6240, Train Metric: 0.0697,  Val Loss: 0.6109, Val Metric: 0.0693
# Epoch 197/200, Train Loss: 0.6196, Train Metric: 0.0696,  Val Loss: 0.6068, Val Metric: 0.0692
# Epoch 198/200, Train Loss: 0.6152, Train Metric: 0.0695,  Val Loss: 0.6030, Val Metric: 0.0691
# Epoch 199/200, Train Loss: 0.6109, Train Metric: 0.0694,  Val Loss: 0.5992, Val Metric: 0.0690
# Epoch 200/200, Train Loss: 0.6065, Train Metric: 0.0692,  Val Loss: 0.5955, Val Metric: 0.0689
# Test Loss: 0.59376, Test Metric: 0.06880

# %%
total_params = sum(p.numel() for p in model_gnn.parameters() if p.requires_grad)
total_params
# Out:
# 438397

# %%
total_params = sum(p.numel() for p in model_fcnn.parameters() if p.requires_grad)
total_params
# Out:
# 24069
